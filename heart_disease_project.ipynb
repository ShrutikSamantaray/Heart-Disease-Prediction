# %%
import pandas as pd

df = pd.read_csv('/content/heart disease.csv')
print(type(df))

df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   52    1   0       125   212    0  ...      0      1.0      2   2     3       0
# 1   53    1   0       140   203    1  ...      1      3.1      0   0     3       0
# 2   70    1   0       145   174    0  ...      1      2.6      0   0     3       0
# 3   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 4   62    0   0       138   294    1  ...      0      1.9      1   3     2       0
#
# [5 rows x 14 columns]

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.head()
print("df.shape -->", df.shape)
print("Rows     -->", df.shape[0])  ##axis 0---row
print("Columns  -->", df.shape[1])   ###column
# Out:
# df.shape --> (1025, 14)
# Rows     --> 1025
# Columns  --> 14

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   52    1   0       125   212    0  ...      0      1.0      2   2     3       0
# 1   53    1   0       140   203    1  ...      1      3.1      0   0     3       0
# 2   70    1   0       145   174    0  ...      1      2.6      0   0     3       0
# 3   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 4   62    0   0       138   294    1  ...      0      1.9      1   3     2       0
#
# [5 rows x 14 columns]

# %%
df.tail()
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.describe()
# Out:
#                age          sex  ...         thal       target
# count  1025.000000  1025.000000  ...  1025.000000  1025.000000
# mean     54.434146     0.695610  ...     2.323902     0.513171
# std       9.072290     0.460373  ...     0.620660     0.500070
# min      29.000000     0.000000  ...     0.000000     0.000000
# 25%      48.000000     0.000000  ...     2.000000     0.000000
# 50%      56.000000     1.000000  ...     2.000000     1.000000
# 75%      61.000000     1.000000  ...     3.000000     1.000000
# max      77.000000     1.000000  ...     3.000000     1.000000
#
# [8 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
import matplotlib.pyplot as plt
print("matplotlib is imported")
# Out:
# matplotlib is imported

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('heart disease.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   52    1   0       125   212    0  ...      0      1.0      2   2     3       0
# 1   53    1   0       140   203    1  ...      1      3.1      0   0     3       0
# 2   70    1   0       145   174    0  ...      1      2.6      0   0     3       0
# 3   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 4   62    0   0       138   294    1  ...      0      1.9      1   3     2       0
#
# [5 rows x 14 columns]

# %%
x = df['age']
y = df['target']

plt.xlabel('age')                                   
plt.ylabel('target')
plt.title('target Vs age')

plt.bar(x, y, color = "purple")

plt.show()

# %%
x = df['age']
y = df['thal']

plt.xlabel('age')                                   
plt.ylabel('thal')
plt.title('thal Vs age')

plt.scatter(x, y, marker = "*")

# marker {'o','+','x','^','*','_'}

plt.show()

# %%
x = df['age']
y = df['target']

plt.xlabel('age')                                   
plt.ylabel('target')
plt.title('target Vs age')
plt.plot(x, y)
plt.savefig("testImage2.jpg", dpi=300)
plt.show()

# %%
x = df['age']
y = df['target']

plt.xlabel('age')                                   
plt.ylabel('target')
plt.title('target Vs age')

plt.bar(y, x, color = "green")

plt.show()

# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
# Out:
# '2.3.5'

# %%
from pycaret.datasets import get_data

# %%
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  ... # Attributes Missing Values
# 0                            anomaly  Multivariate  ...           10              N
# 1                             france  Multivariate  ...            8              N
# 2                            germany  Multivariate  ...            8              N
# 3                               bank  Multivariate  ...           17              N
# 4                              blood  Multivariate  ...            5              N
# 5                             cancer  Multivariate  ...           10              N
# 6                             credit  Multivariate  ...           24              N
# 7                           diabetes  Multivariate  ...            9              N
# 8                    electrical_grid  Multivariate  ...           14              N
# 9                           employee  Multivariate  ...           10              N
# 10                             heart  Multivariate  ...           16              N
# 11                     heart_disease  Multivariate  ...           14              N
# 12                         hepatitis  Multivariate  ...           32              Y
# 13                            income  Multivariate  ...           14              Y
# 14                             juice  Multivariate  ...           15              N
# 15                               nba  Multivariate  ...           21              N
# 16                              wine  Multivariate  ...           13              N
# 17                         telescope  Multivariate  ...           11              N
# 18                           titanic  Multivariate  ...           11              Y
# 19  us_presidential_election_results  Multivariate  ...            7              N
# 20                             glass  Multivariate  ...           10              N
# 21                              iris  Multivariate  ...            5              N
# 22                             poker  Multivariate  ...           11              N
# 23                         questions  Multivariate  ...            4              N
# 24                         satellite  Multivariate  ...           37              N
# 25                               CTG  Multivariate  ...           40              Y
# 26                          asia_gdp  Multivariate  ...           11              N
# 27                         elections  Multivariate  ...           54              Y
# 28                          facebook  Multivariate  ...           12              N
# 29                               ipl  Multivariate  ...           25              N
# 30                         jewellery  Multivariate  ...            4              N
# 31                              mice  Multivariate  ...           82              Y
# 32                         migration  Multivariate  ...           12              N
# 33                           perfume  Multivariate  ...           29              N
# 34                           pokemon  Multivariate  ...           13              Y
# 35                        population  Multivariate  ...           56              Y
# 36                     public_health  Multivariate  ...           21              N
# 37                             seeds  Multivariate  ...            7              N
# 38                         wholesale  Multivariate  ...            8              N
# 39                            tweets          Text  ...            2              N
# 40                            amazon          Text  ...            2              N
# 41                              kiva          Text  ...            7              N
# 42                               spx          Text  ...            4              N
# 43                         wikipedia          Text  ...            3              N
# 44                        automobile  Multivariate  ...           26              Y
# 45                              bike  Multivariate  ...           15              N
# 46                            boston  Multivariate  ...           14              N
# 47                          concrete  Multivariate  ...            9              N
# 48                           diamond  Multivariate  ...            8              N
# 49                            energy  Multivariate  ...           10              N
# 50                            forest  Multivariate  ...           13              N
# 51                              gold  Multivariate  ...          121              N
# 52                             house  Multivariate  ...           81              Y
# 53                         insurance  Multivariate  ...            7              N
# 54                        parkinsons  Multivariate  ...           22              N
# 55                           traffic  Multivariate  ...            8              N
#
# [56 rows x 8 columns]

# %%
heartdiseaseDataSet = get_data("heart_disease")
print(type(heartdiseaseDataSet))
# Out:
#    age  sex  chest pain type  ...  number of major vessels   thal  Disease
# 0   70    1                4  ...                         3     3        1
# 1   67    0                3  ...                         0     7        0
# 2   57    1                2  ...                         0     7        1
# 3   64    1                4  ...                         1     7        0
# 4   74    0                2  ...                         1     3        0
#
# [5 rows x 14 columns]
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd
heartdiseaseDataSet = pd.read_csv("heart disease.csv")

# %%
heartdiseaseDataSet.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heartdiseaseDataSet.describe()
# Out:
#                age          sex  ...         thal       target
# count  1025.000000  1025.000000  ...  1025.000000  1025.000000
# mean     54.434146     0.695610  ...     2.323902     0.513171
# std       9.072290     0.460373  ...     0.620660     0.500070
# min      29.000000     0.000000  ...     0.000000     0.000000
# 25%      48.000000     0.000000  ...     2.000000     0.000000
# 50%      56.000000     1.000000  ...     2.000000     1.000000
# 75%      61.000000     1.000000  ...     3.000000     1.000000
# max      77.000000     1.000000  ...     3.000000     1.000000
#
# [8 rows x 14 columns]

# %%
print("type(heartdiseaseDataSet)-->",type(heartdiseaseDataSet))
# Out:
# type(heartdiseaseDataSet)--> <class 'pandas.core.frame.DataFrame'>

# %%
print("heartdiseaseDataSet.shape -->", heartdiseaseDataSet.shape)
print("Rows     -->", heartdiseaseDataSet.shape[0])  ##axis 0---row
print("Columns  -->", heartdiseaseDataSet.shape[1])   ###column
# Out:
# heartdiseaseDataSet.shape --> (1025, 14)
# Rows     --> 1025
# Columns  --> 14

# %%
heartdiseaseDataSet.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  target
# 0   52    1   0       125   212    0  ...      0      1.0      2   2     3       0
# 1   53    1   0       140   203    1  ...      1      3.1      0   0     3       0
# 2   70    1   0       145   174    0  ...      1      2.6      0   0     3       0
# 3   61    1   0       148   203    0  ...      0      0.0      2   1     3       0
# 4   62    0   0       138   294    1  ...      0      1.9      1   3     2       0
#
# [5 rows x 14 columns]

# %%
heartdiseaseDataSet.loc[10:100 , ['target','age']]
# Out:
#      target  age
# 10        1   71
# 11        0   43
# 12        1   34
# 13        0   51
# 14        0   52
# ..      ...  ...
# 96        1   57
# 97        0   53
# 98        0   65
# 99        1   76
# 100       1   43
#
# [91 rows x 2 columns]

# %%
heartdiseaseDataSet.iloc[20:30, 1:5]
# Out:
#     sex  cp  trestbps  chol
# 20    1   2       140   185
# 21    0   0       106   223
# 22    1   0       104   208
# 23    0   2       135   252
# 24    0   2       120   209
# 25    0   0       145   307
# 26    1   2       130   233
# 27    0   1       136   319
# 28    1   2       130   256
# 29    0   0       180   327

# %%
heartdiseaseDataSet.mean()
# Out:
# age          54.434146
# sex           0.695610
# cp            0.942439
# trestbps    131.611707
# chol        246.000000
# fbs           0.149268
# restecg       0.529756
# thalach     149.114146
# exang         0.336585
# oldpeak       1.071512
# slope         1.385366
# ca            0.754146
# thal          2.323902
# target        0.513171
# dtype: float64

# %%
heartdiseaseDataSet.max()
# Out:
# age          77.0
# sex           1.0
# cp            3.0
# trestbps    200.0
# chol        564.0
# fbs           1.0
# restecg       2.0
# thalach     202.0
# exang         1.0
# oldpeak       6.2
# slope         2.0
# ca            4.0
# thal          3.0
# target        1.0
# dtype: float64

# %%
heartdiseaseDataSet.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
heartdiseaseDataSet.dropna(axis = 'columns')
# Out:
#       age  sex  cp  trestbps  chol  ...  oldpeak  slope  ca  thal  target
# 0      52    1   0       125   212  ...      1.0      2   2     3       0
# 1      53    1   0       140   203  ...      3.1      0   0     3       0
# 2      70    1   0       145   174  ...      2.6      0   0     3       0
# 3      61    1   0       148   203  ...      0.0      2   1     3       0
# 4      62    0   0       138   294  ...      1.9      1   3     2       0
# ...   ...  ...  ..       ...   ...  ...      ...    ...  ..   ...     ...
# 1020   59    1   1       140   221  ...      0.0      2   0     2       1
# 1021   60    1   0       125   258  ...      2.8      1   1     3       0
# 1022   47    1   0       110   275  ...      1.0      1   1     2       0
# 1023   50    0   0       110   254  ...      0.0      2   0     2       1
# 1024   54    1   0       120   188  ...      1.4      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
heartdiseaseDataSet.fillna(0)
# Out:
#      Number of times pregnant  ...  Class variable
# 0                           6  ...               1
# 1                           1  ...               0
# 2                           8  ...               1
# 3                           1  ...               0
# 4                           0  ...               1
# ..                        ...  ...             ...
# 763                        10  ...               0
# 764                         2  ...               0
# 765                         5  ...               0
# 766                         1  ...               1
# 767                         1  ...               0
#
# [768 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
x = heartdiseaseDataSet['age']

plt.xlabel('age')                                   
plt.ylabel('target')
plt.title('target Vs age')

plt.hist(x, color = "red", bins=50)

plt.show()

# %%
import matplotlib.pyplot as plt

# %%
## Scatter plot
import matplotlib.pyplot as plt
x = heartdiseaseDataSet['age']
y = heartdiseaseDataSet['thal']

plt.xlabel('age')                                   
plt.ylabel('thal')
plt.title('thal Vs age')

plt.scatter(x, y, marker = "*",color = "red")

plt.show()

# %%
import matplotlib.pyplot as plt
x=tuple(range(768))
x = heartdiseaseDataSet['age']
y = heartdiseaseDataSet['target']

plt.xlabel('age')                                   
plt.ylabel('target')
plt.title('target Vs age')
plt.subplot(121)
plt.hist(x, color = "red", bins=50)
#########################################################################
x = heartdiseaseDataSet['age']
y = heartdiseaseDataSet['target']

plt.xlabel('age')                                   
plt.ylabel('target')
plt.title('target Vs age')
plt.subplot(122)
plt.scatter(x, y, marker = "*",color = "red")

plt.show()

# %% [markdown]
# ## RANDOM FOREST MODEL

# %%
from pycaret.classification import *

heartdiseaseDataSet = get_data("diabetes")
s = setup(data=heartdiseaseDataSet, target='Class variable', silent=True)

rfModel = create_model('rf')
plot_model(rfModel, plot='confusion_matrix')

# %% [markdown]
# ## ADA BOOST CLASSIFIER

# %%
from pycaret.classification import *

heartdiseaseDataSet = get_data("diabetes")
s = setup(data=heartdiseaseDataSet, target='Class variable', silent=True)

adaModel=create_model('ada')
plot_model(adaModel, plot='confusion_matrix')

# %% [markdown]
# ## DECISION TREE CLASSIFIER

# %%
from pycaret.classification import *

heartdiseaseDataSet = get_data("diabetes")
s = setup(data=heartdiseaseDataSet, target='Class variable', silent=True)

dtModel=create_model('dt')
plot_model(dtModel, plot='confusion_matrix')

# %% [markdown]
# ## LINEAR DISCRIMINANT ANALYSIS

# %%
from pycaret.classification import *

heartdiseaseDataSet = get_data("diabetes")
s = setup(data=heartdiseaseDataSet, target='Class variable', silent=True)

ldaModel=create_model('lda')
plot_model(ldaModel, plot='confusion_matrix')

# %%
sm = save_model(rfModel, 'rfModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
sm = save_model(adaModel, 'adaModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
sm = save_model(dtModel, 'dtModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
sm = save_model(ldaModel, 'ldaModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
rfModel = create_model('rf', verbose=True)
plot_model(rfModel, plot='feature')

# %%
adaModel = create_model('ada', verbose=True)
plot_model(adaModel, plot='feature')

# %%
dtModel = create_model('dt', verbose=True)
plot_model(dtModel, plot='feature')

# %%
ldaModel = create_model('lda', verbose=True)
plot_model(ldaModel, plot='feature')

# %%
from pycaret.classification import *
s = setup(data=heartdiseaseDataSet, target='Class variable', silent=True)
# Out:
#                                Description             Value
# 0                               session_id              7473
# 1                                   Target    Class variable
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data          (768, 9)
# 5                           Missing Values             False
# 6                         Numeric Features                 7
# 7                     Categorical Features                 1
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set         (537, 23)
# 12                    Transformed Test Set         (231, 23)
# 13                      Shuffle Train-Test              True
# 14                     Stratify Train-Test             False
# 15                          Fold Generator   StratifiedKFold
# 16                             Fold Number                10
# 17                                CPU Jobs                -1
# 18                                 Use GPU             False
# 19                          Log Experiment             False
# 20                         Experiment Name  clf-default-name
# 21                                     USI              321c
# 22                         Imputation Type            simple
# 23          Iterative Imputation Iteration              None
# 24                         Numeric Imputer              mean
# 25      Iterative Imputation Numeric Model              None
# 26                     Categorical Imputer          constant
# 27  Iterative Imputation Categorical Model              None
# 28           Unknown Categoricals Handling    least_frequent
# 29                               Normalize             False
# 30                        Normalize Method              None
# 31                          Transformation             False
# 32                   Transformation Method              None
# 33                                     PCA             False
# 34                              PCA Method              None
# 35                          PCA Components              None
# 36                     Ignore Low Variance             False
# 37                     Combine Rare Levels             False
# 38                    Rare Level Threshold              None
# 39                         Numeric Binning             False
# 40                         Remove Outliers             False
# 41                      Outliers Threshold              None
# 42                Remove Multicollinearity             False
# 43             Multicollinearity Threshold              None
# 44             Remove Perfect Collinearity              True
# 45                              Clustering             False
# 46                    Clustering Iteration              None
# 47                     Polynomial Features             False
# 48                       Polynomial Degree              None
# 49                    Trignometry Features             False
# 50                    Polynomial Threshold              None
# 51                          Group Features             False
# 52                       Feature Selection             False
# 53                Feature Selection Method           classic
# 54            Features Selection Threshold              None
# 55                     Feature Interaction             False
# 56                           Feature Ratio             False
# 57                   Interaction Threshold              None
# 58                           Fix Imbalance             False
# 59                    Fix Imbalance Method             SMOTE

# %%
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.7971  0.8283  0.6232  0.7681
# et                 Extra Trees Classifier    0.7727  0.8099  0.5550  0.7570
# lr                    Logistic Regression    0.7709  0.8290  0.5966  0.7227
# ridge                    Ridge Classifier    0.7690  0.0000  0.5863  0.7229
# lda          Linear Discriminant Analysis    0.7672  0.8234  0.5863  0.7189
# gbc          Gradient Boosting Classifier    0.7654  0.8279  0.6174  0.6947
# lightgbm  Light Gradient Boosting Machine    0.7654  0.8111  0.6495  0.6792
# ada                  Ada Boost Classifier    0.7597  0.8125  0.5858  0.6912
# knn                K Neighbors Classifier    0.7373  0.7676  0.5805  0.6463
# nb                            Naive Bayes    0.7022  0.7323  0.2979  0.7060
# dt               Decision Tree Classifier    0.7001  0.6790  0.6068  0.5727
# dummy                    Dummy Classifier    0.6443  0.5000  0.0000  0.0000
# qda       Quadratic Discriminant Analysis    0.6253  0.6363  0.4692  0.5370
# svm                   SVM - Linear Kernel    0.6184  0.0000  0.3789  0.3903
#
#               F1   Kappa     MCC  TT (Sec)
# rf        0.6840  0.5375  0.5466     0.519
# et        0.6294  0.4728  0.4911     0.465
# lr        0.6480  0.4811  0.4899     0.272
# ridge     0.6427  0.4752  0.4843     0.015
# lda       0.6412  0.4719  0.4806     0.017
# gbc       0.6491  0.4746  0.4801     0.130
# lightgbm  0.6617  0.4827  0.4847     0.090
# ada       0.6309  0.4554  0.4608     0.112
# knn       0.6078  0.4120  0.4162     0.117
# nb        0.4128  0.2548  0.3007     0.017
# dt        0.5854  0.3517  0.3546     0.017
# dummy     0.0000  0.0000  0.0000     0.015
# qda       0.4388  0.1845  0.2032     0.019
# svm       0.3233  0.1207  0.1320     0.016

# %%
from pycaret.datasets import get_data
from pycaret.classification import *

heartDiseaseDataSet = get_data("heart disease")
s = setup(data = heartDiseaseDataSet, target='target', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.9888  0.9994  0.9973  0.9821
# rf               Random Forest Classifier    0.9874  0.9985  0.9946  0.9818
# lightgbm  Light Gradient Boosting Machine    0.9860  0.9989  0.9973  0.9767
# dt               Decision Tree Classifier    0.9707  0.9704  0.9785  0.9665
# gbc          Gradient Boosting Classifier    0.9540  0.9914  0.9568  0.9563
# ada                  Ada Boost Classifier    0.8856  0.9587  0.9031  0.8838
# ridge                    Ridge Classifier    0.8606  0.0000  0.9061  0.8408
# lr                    Logistic Regression    0.8592  0.9266  0.8953  0.8456
# lda          Linear Discriminant Analysis    0.8592  0.9270  0.9061  0.8390
# nb                            Naive Bayes    0.8271  0.8891  0.8466  0.8245
# knn                K Neighbors Classifier    0.7349  0.8311  0.7307  0.7586
# qda       Quadratic Discriminant Analysis    0.6929  0.6902  0.7602  0.6980
# svm                   SVM - Linear Kernel    0.5856  0.0000  0.5892  0.6515
# dummy                    Dummy Classifier    0.5174  0.5000  1.0000  0.5174
#
#               F1   Kappa     MCC  TT (Sec)
# et        0.9894  0.9775  0.9781     0.464
# rf        0.9880  0.9747  0.9752     0.517
# lightgbm  0.9867  0.9719  0.9726     0.058
# dt        0.9721  0.9413  0.9420     0.018
# gbc       0.9553  0.9078  0.9102     0.138
# ada       0.8912  0.7706  0.7750     0.117
# ridge     0.8710  0.7199  0.7252     0.016
# lr        0.8679  0.7175  0.7225     0.277
# lda       0.8699  0.7171  0.7227     0.021
# nb        0.8347  0.6535  0.6550     0.017
# knn       0.7397  0.4694  0.4752     0.120
# qda       0.7186  0.3815  0.3960     0.020
# svm       0.5311  0.1668  0.2212     0.022
# dummy     0.6820  0.0000  0.0000     0.014

# %%
s = setup(data=heartdiseaseDataSet, target='Class variable', normalize = True, normalize_method = 'zscore', silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7709  0.8328  0.5737  0.7245
# ridge                    Ridge Classifier    0.7673  0.0000  0.5526  0.7272
# gbc          Gradient Boosting Classifier    0.7618  0.8338  0.6000  0.6862
# lda          Linear Discriminant Analysis    0.7617  0.8261  0.5474  0.7172
# rf               Random Forest Classifier    0.7580  0.8333  0.5789  0.6919
# ada                  Ada Boost Classifier    0.7487  0.8051  0.6105  0.6556
# lightgbm  Light Gradient Boosting Machine    0.7375  0.7997  0.5842  0.6456
# svm                   SVM - Linear Kernel    0.7358  0.0000  0.5895  0.6368
# et                 Extra Trees Classifier    0.7318  0.8020  0.5263  0.6519
# knn                K Neighbors Classifier    0.7207  0.7583  0.5105  0.6305
# dt               Decision Tree Classifier    0.7022  0.6779  0.5947  0.5790
# nb                            Naive Bayes    0.6908  0.7427  0.3158  0.6365
# qda       Quadratic Discriminant Analysis    0.6517  0.6306  0.4579  0.4822
# dummy                    Dummy Classifier    0.6462  0.5000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.6367  0.4736  0.4828     0.028
# ridge     0.6240  0.4610  0.4727     0.014
# gbc       0.6368  0.4618  0.4663     0.127
# lda       0.6166  0.4491  0.4606     0.018
# rf        0.6287  0.4514  0.4567     0.507
# ada       0.6289  0.4401  0.4433     0.114
# lightgbm  0.6105  0.4139  0.4172     0.054
# svm       0.6070  0.4101  0.4140     0.017
# et        0.5799  0.3867  0.3931     0.465
# knn       0.5599  0.3601  0.3668     0.116
# dt        0.5843  0.3532  0.3551     0.019
# nb        0.4142  0.2375  0.2677     0.017
# qda       0.4416  0.2094  0.2195     0.017
# dummy     0.0000  0.0000  0.0000     0.014

# %%
s = setup(data=heartdiseaseDataSet, target='Class variable', feature_selection = True, feature_selection_threshold = 0.6, silent=True)
cm = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lr                    Logistic Regression    0.7522  0.8004  0.5360  0.6874
# lda          Linear Discriminant Analysis    0.7485  0.7989  0.5249  0.6841
# rf               Random Forest Classifier    0.7467  0.8125  0.5254  0.6793
# gbc          Gradient Boosting Classifier    0.7449  0.8065  0.5588  0.6542
# ridge                    Ridge Classifier    0.7447  0.0000  0.5137  0.6805
# ada                  Ada Boost Classifier    0.7243  0.7783  0.5365  0.6197
# lightgbm  Light Gradient Boosting Machine    0.7225  0.7788  0.5526  0.6043
# et                 Extra Trees Classifier    0.7188  0.7580  0.4749  0.6253
# knn                K Neighbors Classifier    0.6943  0.7255  0.4637  0.5735
# dt               Decision Tree Classifier    0.6775  0.6425  0.5360  0.5349
# dummy                    Dummy Classifier    0.6629  0.5000  0.0000  0.0000
# nb                            Naive Bayes    0.6592  0.7392  0.1927  0.4236
# svm                   SVM - Linear Kernel    0.6463  0.0000  0.3000  0.4413
# qda       Quadratic Discriminant Analysis    0.5433  0.5831  0.6088  0.4410
#
#               F1   Kappa     MCC  TT (Sec)
# lr        0.5933  0.4199  0.4322     0.235
# lda       0.5822  0.4083  0.4227     0.017
# rf        0.5827  0.4063  0.4192     0.512
# gbc       0.5935  0.4109  0.4197     0.127
# ridge     0.5730  0.3977  0.4130     0.014
# ada       0.5625  0.3661  0.3762     0.112
# lightgbm  0.5697  0.3670  0.3727     0.048
# et        0.5322  0.3373  0.3484     0.462
# knn       0.5081  0.2899  0.2967     0.117
# dt        0.5310  0.2867  0.2888     0.017
# dummy     0.0000  0.0000  0.0000     0.011
# nb        0.2545  0.0995  0.1119     0.016
# svm       0.3025  0.1313  0.1501     0.019
# qda       0.4708  0.1258  0.1105     0.017
